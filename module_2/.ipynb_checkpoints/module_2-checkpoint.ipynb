# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind
import numpy as np
pd.set_option('display.max_rows', 50) # показывать больше строк
pd.set_option('display.max_columns', 50) # показывать больше колонок

stud = pd.read_csv('stud_math.csv')

# %%
display(stud.head(12))
stud.info()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0      GP   F   18       U     NaN       A   4.0   4.0   at_home  teacher
# 1      GP   F   17       U     GT3     NaN   1.0   1.0   at_home    other
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home    other
# 3      GP   F   15       U     GT3       T   4.0   2.0    health      NaN
# 4      GP   F   16       U     GT3       T   3.0   3.0     other    other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services    other
# 6      GP   M   16     NaN     LE3       T   2.0   2.0     other    other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other  teacher
# 8      GP   M   15       U     LE3       A   3.0   2.0  services    other
# 9      GP   M   15       U     NaN     NaN   3.0   4.0     other    other
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher   health
# 11     GP   F   15       U     GT3     NaN   2.0  40.0  services    other
#
# ...

# %%
sns.heatmap(stud.corr(), annot=True)
plt.gcf().set_size_inches(10, 8)

# %%
stud.drop(['studytime, granular'], axis=1, inplace=True) 
#удаляем столбец 'studytime, granular', тк он полностью коррелирует со столбцом 'studytime'

# %%
sns.heatmap(stud.corr(), annot=True)
plt.gcf().set_size_inches(10, 8)

# %%
"""1 school — аббревиатура школы, в которой учится ученик"""
# Out:
# '1 school — аббревиатура школы, в которой учится ученик'

# %%
pd.DataFrame(stud.school.value_counts()) 
# категориальная переменная, пропусков нет, выбросов нет, вижу, что есть две школы GP и MS
# большая часть детей учится в GP
# выбросов тоже нет
# Out:
#     school
# GP     349
# MS      46

# %%
sns.boxplot(x='score', y='school', data=stud)

# %%
"""2 sex — пол ученика ('F' - женский, 'M' - мужской)"""
# Out:
# "2 sex — пол ученика ('F' - женский, 'M' - мужской)"

# %%
pd.DataFrame(stud.sex.value_counts()) # пропусков нет, выбросов тоже
# Out:
#    sex
# F  208
# M  187

# %%
sns.boxplot(x='score', y='sex', data=stud)
# судя по этому боксплоту, у мальчиков успеваемость выше

# %%
"""3 age — возраст ученика (от 15 до 22)"""
# Out:
# '3 age — возраст ученика (от 15 до 22)'

# %%
stud.age.hist() # age числовой столбец, посмотрю распределение
stud.age.describe() # выбросов не вижу, все в пределах нормы, пропусков нет
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
pd.DataFrame(stud.age.value_counts())
# Out:
#     age
# 16  104
# 17   98
# 18   82
# 15   82
# 19   24
# 20    3
# 22    1
# 21    1

# %%
"""
Из графика видно, что бОльшая часть учеников в возрасте. от 15 до 17 лет
min 15, max 22. медиана почти совпадает со средним.
Данные с 20 до 22х можно принять за выбросы, но думаю это норма, так как в датасете дети 
от 15 до 22х лет.
Просто детей от 20 до 22х лет не так много, а именно 5 человек
"""
# Out:
# '\nИз графика видно, что бОльшая часть учеников в возрасте. от 15 до 17 лет\nmin 15, max 22. медиана почти совпадает со средним.\nДанные с 20 до 22х можно принять за выбросы, но думаю это норма, так как в датасете дети \nот 15 до 22х лет.\nПросто детей от 20 до 22х лет не так много, а именно 5 человек\n'

# %%
sns.boxplot(x = stud['age'], y = stud['score']) 
"""
интересное распределение score
в зависимости от возраста. Снижение score с 17 до 19 лет. А потом резкое увеличение score
в 20 лет. Возможно это связано с половым созреванием? :)
сначала так подумал, но 20ти летних всего 3 человека, возможно это не закономерность
"""
# Out:
# '\nинтересное распределение score\nв зависимости от возраста. Снижение score с 17 до 19 лет. А потом резкое увеличение score\nв 20 лет. Возможно это связано с половым созреванием? :)\nсначала так подумал, но 20ти летних всего 3 человека, возможно это не закономерность\n'

# %%
"""4 address — тип адреса ученика ('U' - городской, 'R' - за городом)"""
# Out:
# "4 address — тип адреса ученика ('U' - городской, 'R' - за городом)"

# %%
pd.DataFrame(stud.address.value_counts())
# Out:
#    address
# U      295
# R       83

# %%
len(stud.address.loc[stud.address.isnull() == 1]) 
# Категориальный признак, выбросов нет, есть 17 пропусков
# Out:
# 17

# %%
sns.boxplot(x = stud['address'], y = stud['score'])
# Городские с более высокой успеваемостью, чем загородные

# %%
stud.address.describe()
# Out:
# count     378
# unique      2
# top         U
# freq      295
# Name: address, dtype: object

# %%
stud[stud.address.isnull()] # посмотрю на пропуски, в основном по школе GP
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 6       GP   M   16     NaN     LE3       T   2.0   2.0     other     other
# 52      GP   M   15     NaN     LE3       A   4.0   2.0    health       NaN
# 75      GP   M   15     NaN     GT3       T   4.0   3.0   teacher     other
# 92      GP   F   16     NaN     LE3       T   NaN   1.0     other     other
# 96      GP   M   16     NaN     GT3     NaN   4.0   3.0  services     other
# 159     GP   M   16     NaN     GT3       T   3.0   NaN     other  services
# 168     GP   F   16     NaN     GT3       T   2.0   2.0     other     other
# 241     GP   M   17     NaN     LE3       A   4.0   4.0   teacher     other
# 254     GP   M   17     NaN     NaN       T   2.0   1.0     other     other
# 270     GP   F   19     NaN     GT3       T   3.0   3.0     other  services
# 292     GP   F   18     NaN     LE3       T   2.0   1.0  services   at_home
# ...

# %%
# заменю пропуски на самое часто встречающееся значение U
stud['address'] = stud.apply(lambda x: 'U' if pd.isna(x.address)else x.address , axis=1)

# %%
stud.address.describe()
# Out:
# count     395
# unique      2
# top         U
# freq      312
# Name: address, dtype: object

# %%
sns.boxplot(x = stud['address'], y = stud['score'])

# %%
"""5 famsize — размер семьи('LE3' <= 3, 'GT3' >3)"""
# Out:
# "5 famsize — размер семьи('LE3' <= 3, 'GT3' >3)"

# %%
sns.boxplot(x = stud['famsize'], y = stud['score']) 
# судя по боксплоту, размер семьи почти не влияет на успеваемость

# %%
pd.DataFrame(stud.famsize.value_counts()) 
# категориальная переменная, выбросов нет
# Out:
#      famsize
# GT3      261
# LE3      107

# %%
len(stud.famsize.loc[stud.famsize.isnull() == 1]) # есть 27 пропусков
# Out:
# 27

# %%
stud.famsize.describe()
# Out:
# count     368
# unique      2
# top       GT3
# freq      261
# Name: famsize, dtype: object

# %%
# заменю пропуски на самое часто встречающееся значение GT3
stud['famsize'] = stud.apply(lambda x: 'GT3' if pd.isna(x.famsize)else x.famsize , axis=1)

# %%
len(stud.famsize.loc[stud.famsize.isnull() == 1])
# Out:
# 0

# %%
stud.famsize.describe()
# Out:
# count     395
# unique      2
# top       GT3
# freq      288
# Name: famsize, dtype: object

# %%
"""6 Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)"""
# Out:
# "6 Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)"

# %%
sns.boxplot(x = stud['Pstatus'], y = stud['score'])

# %%
pd.DataFrame(stud.Pstatus.value_counts())
# Out:
#    Pstatus
# T      314
# A       36

# %%
len(stud.Pstatus.loc[stud.Pstatus.isnull() == 1])
# Out:
# 45

# %%
# признак категориальный. Достаточно много пропусков. 
# Произвести замены можно сравнив эту колонку с колонкой "famsize" - размер семьи.
# Если в семье 3 человека и более, то родители живут вместе и замена на "Т"
# Если меньше 3х, то замена на "А"

# %%
stud['Pstatus'] = stud.apply(lambda x: ('T' if x.famsize == 'GT3' else 'A') if pd.isna(x.Pstatus) else x.Pstatus , axis=1)

# %%
pd.DataFrame(stud.Pstatus.value_counts())
# Out:
#    Pstatus
# T      346
# A       49

# %%
len(stud.Pstatus.loc[stud.Pstatus.isnull() == 1])
# Out:
# 0

# %%
"""7 Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 
3 - среднее специальное или 11 классов, 4 - высшее)"""
# Out:
# '7 Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, \n3 - среднее специальное или 11 классов, 4 - высшее)'

# %%
stud.Medu.hist()
stud.Medu.describe()
# Out:
# count    392.000000
# mean       2.750000
# std        1.098127
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64

# %%
# признак категориальный, хоть и числовой, выбросов нет, есть 3 пропуска данных
len(stud.Medu.loc[stud.Medu.isnull() == 1])
# Out:
# 3

# %%
# заменю пропуски значением, которое наиболее близко к среднему(среднее 2.75) - 3
stud.Medu = stud.Medu.fillna(3.0)

# %%
stud.Medu.hist()
stud.Medu.describe()
# Out:
# count    395.000000
# mean       2.751899
# std        1.094154
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64

# %%
"""8 Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 
3 - среднее специальное или 11 классов, 4 - высшее)"""
# Out:
# '8 Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, \n3 - среднее специальное или 11 классов, 4 - высшее)'

# %%
stud.Fedu.hist()
stud.Fedu.describe()
# Out:
# count    371.000000
# mean       2.614555
# std        2.228732
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       40.000000
# Name: Fedu, dtype: float64

# %%
stud.Fedu.value_counts() # категориальная переменная, найден один выброс, скорей всего при 
# сборе\вводе данных была допущена ошибка, вместо оценки 4.0 поставили 40.0
# так как это единичный случай, лучше исправить 40 на 4.0
# Out:
# 2.0     106
# 3.0      96
# 4.0      88
# 1.0      78
# 0.0       2
# 40.0      1
# Name: Fedu, dtype: int64

# %%
stud.Fedu.loc[stud.Fedu == 40]
# Out:
# 11    40.0
# Name: Fedu, dtype: float64

# %%
stud.Fedu[11] = stud.Fedu[11] == 4.0 # решил заменить значение
stud["Fedu"] = pd.to_numeric(stud["Fedu"]) # вернул тип на числовой
# Out:
# <ipython-input-1146-cbe0ae996fc6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stud.Fedu[11] = stud.Fedu[11] == 4.0 # решил заменить значение
# /Users/idiamond/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
stud.Fedu.hist()
stud.Fedu.describe()
# Out:
# count    371.000000
# mean       2.506739
# std        1.093881
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Fedu, dtype: float64

# %%
len(stud.Fedu.loc[stud.Fedu.isnull() == 1]) # есть 24 пропуска
# заменю пропуски на близкое среднее значение
# Out:
# 24

# %%
stud.Fedu = stud.Fedu.fillna(3.0)

# %%
stud.Fedu.describe()
# Out:
# count    395.000000
# mean       2.536709
# std        1.066587
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        4.000000
# Name: Fedu, dtype: float64

# %%
"""9 Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 
'other' - другое)"""
# Out:
# "9 Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, \n'other' - другое)"

# %%
stud.Mjob.hist()
stud.Mjob.describe()
# Out:
# count       376
# unique        5
# top       other
# freq        133
# Name: Mjob, dtype: object

# %%
len(stud.Mjob.loc[stud.Mjob.isnull() == 1])
# Out:
# 19

# %%
# категориальный признак, выбросов нет, 19 пропусков

# %%
sns.boxplot(x = stud['Mjob'], y = stud['score']) # посмотрю как влияет на целевую переменную

# %%
stud.Mjob = stud.Mjob.fillna('other') #пропуски заменю на самое частое значение other

# %%
"""
10 Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 
'services' - гос служба, 'at_home' - не работает, 'other' - другое)
"""
# Out:
# "\n10 Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, \n'services' - гос служба, 'at_home' - не работает, 'other' - другое)\n"

# %%
stud.Fjob.hist()
stud.Fjob.describe() # категориальная переменная, выбросов нет
# Out:
# count       359
# unique        5
# top       other
# freq        197
# Name: Fjob, dtype: object

# %%
len(stud.Fjob.loc[stud.Fjob.isnull() == 1])  #36 пропусков
# Out:
# 36

# %%
sns.boxplot(x = stud['Fjob'], y = stud['score']) # посмотрю как влияет на целевую переменную

# %%
stud.Fjob = stud.Fjob.fillna('other') # пропуски также заменю на самое частое значение other

# %%
"""
11 reason — причина выбора школы ('home' - близость к дому, 
'reputation' - репутация школы, 'course' - образовательная программа,'other' - другое)
"""
# Out:
# "\n11 reason — причина выбора школы ('home' - близость к дому, \n'reputation' - репутация школы, 'course' - образовательная программа,'other' - другое)\n"

# %%
stud.reason.hist()
stud.reason.describe()
# Out:
# count        378
# unique         4
# top       course
# freq         137
# Name: reason, dtype: object

# %%
sns.boxplot(x = stud['reason'], y = stud['score']) # посмотрю как влияет на целевую переменную

# %%
len(stud.reason.loc[stud.reason.isnull() == 1]) 
# категориальная переменная. выбросов нет, 17 пропусков
# Out:
# 17

# %%
stud.reason = stud.reason.fillna('course') # пропуски также заменю на самое частое значение

# %%
stud.reason.describe()
# Out:
# count        395
# unique         4
# top       course
# freq         154
# Name: reason, dtype: object

# %%
"""12 guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)"""
# Out:
# "12 guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)"

# %%
stud.guardian.hist()
stud.guardian.describe()
# Out:
# count        364
# unique         3
# top       mother
# freq         250
# Name: guardian, dtype: object

# %%
sns.boxplot(x = stud['guardian'], y = stud['score']) # посмотрю как влияет на целевую переменную

# %%
len(stud.guardian.loc[stud.guardian.isnull() == 1]) 
# категориальная переменная. выбросов нет, 31 пропуск
# Out:
# 31

# %%
stud.guardian = stud.guardian.fillna('mother') # пропуски также заменю на самое частое значение

# %%
stud.guardian.describe()
# Out:
# count        395
# unique         3
# top       mother
# freq         281
# Name: guardian, dtype: object

# %%
"""
13 traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин.,3 - 30-60 мин., 4 - >60 мин.)
"""
# Out:
# '\n13 traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин.,3 - 30-60 мин., 4 - >60 мин.)\n'

# %%
stud.traveltime.hist()
stud.traveltime.describe()
# Out:
# count    367.000000
# mean       1.438692
# std        0.694181
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: traveltime, dtype: float64

# %%
sns.boxplot(x = stud['traveltime'], y = stud['score']) # посмотрю как влияет на целевую переменную

# %%
len(stud.traveltime.loc[stud.traveltime.isnull() == 1]) 
# категориальная переменная. выбросов нет, 28 пропусков
# Out:
# 28

# %%
stud.traveltime = stud.traveltime.fillna(1.0) 
# пропуски также заменю на самое частое значение

# %%
stud.traveltime.describe()
# Out:
# count    395.000000
# mean       1.407595
# std        0.678490
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: traveltime, dtype: float64

# %%
"""
14 studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 
3 - 5-10 часов, 4 - >10 часов)
"""
# Out:
# '\n14 studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, \n3 - 5-10 часов, 4 - >10 часов)\n'

# %%
stud.studytime.hist()
stud.studytime.describe()
# Out:
# count    388.000000
# mean       2.038660
# std        0.842078
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: studytime, dtype: float64

# %%
sns.boxplot(x = stud['studytime'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.studytime.loc[stud.studytime.isnull() == 1]) 
# категориальная переменная. выбросов нет, 7 пропусков
# Out:
# 7

# %%
stud.studytime = stud.studytime.fillna(2.0) 
# пропуски также заменю на самое частое значение

# %%
stud.studytime.describe()
# Out:
# count    395.000000
# mean       2.037975
# std        0.834580
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: studytime, dtype: float64

# %%
"""
15 failures — количество внеучебных неудач (n, если 1<=n<=3, иначе 0)
"""
# Out:
# '\n15 failures — количество внеучебных неудач (n, если 1<=n<=3, иначе 0)\n'

# %%
stud.failures.hist()
stud.failures.describe()
# Out:
# count    373.000000
# mean       0.337802
# std        0.743135
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: failures, dtype: float64

# %%
sns.boxplot(x = stud['failures'], y = stud['score']) 
# посмотрю как влияет на целевую переменнуюƒ

# %%
len(stud.failures.loc[stud.failures.isnull() == 1])
# категориальная переменная. выбросов нет, 22 пропуска
# Out:
# 22

# %%
stud.failures = stud.failures.fillna(0) 
# пропуски заменю на самое частое значение

# %%
stud.failures.describe()
# Out:
# count    395.000000
# mean       0.318987
# std        0.726244
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: failures, dtype: float64

# %%
"""
16 schoolsup — дополнительная образовательная поддержка (yes или no)
"""
# Out:
# '\n16 schoolsup — дополнительная образовательная поддержка (yes или no)\n'

# %%
stud.schoolsup.hist()
stud.schoolsup.describe()
# Out:
# count     386
# unique      2
# top        no
# freq      335
# Name: schoolsup, dtype: object

# %%
sns.boxplot(x = stud['schoolsup'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.schoolsup.loc[stud.schoolsup.isnull() == 1])
# категориальная переменная. выбросов нет, 9 пропусков
# Out:
# 9

# %%
stud.schoolsup = stud.schoolsup.fillna('no') 
# пропуски заменю на самое частое значение

# %%
stud.schoolsup.describe()
# Out:
# count     395
# unique      2
# top        no
# freq      344
# Name: schoolsup, dtype: object

# %%
"""
17 famsup — семейная образовательная поддержка (yes или no)
"""
# Out:
# '\n17 famsup — семейная образовательная поддержка (yes или no)\n'

# %%
stud.famsup.hist()
stud.famsup.describe()
# Out:
# count     356
# unique      2
# top       yes
# freq      219
# Name: famsup, dtype: object

# %%
sns.boxplot(x = stud['famsup'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.famsup.loc[stud.famsup.isnull() == 1])
# категориальная переменная. выбросов нет, 39 пропусков
# Out:
# 39

# %%
stud.famsup = stud.famsup.fillna('yes')
# пропуски заменю на самое частое значение

# %%
stud.famsup.describe()
# Out:
# count     395
# unique      2
# top       yes
# freq      258
# Name: famsup, dtype: object

# %%
"""
18 paid — дополнительные платные занятия по математике (yes или no)
"""
# Out:
# '\n18 paid — дополнительные платные занятия по математике (yes или no)\n'

# %%
stud.paid.hist()
stud.paid.describe()
# Out:
# count     355
# unique      2
# top        no
# freq      200
# Name: paid, dtype: object

# %%
sns.boxplot(x = stud['paid'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.paid.loc[stud.paid.isnull() == 1])
# категориальная переменная. выбросов нет, 40 пропусков
# Out:
# 40

# %%
stud.paid = stud.paid.fillna('no')
# пропуски заменю на самое частое значение

# %%
stud.paid.describe()
# Out:
# count     395
# unique      2
# top        no
# freq      240
# Name: paid, dtype: object

# %%
"""
19 activities — дополнительные внеучебные занятия (yes или no)
"""
# Out:
# '\n19 activities — дополнительные внеучебные занятия (yes или no)\n'

# %%
stud.activities.hist()
stud.activities.describe()
# Out:
# count     381
# unique      2
# top       yes
# freq      195
# Name: activities, dtype: object

# %%
sns.boxplot(x = stud['activities'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.activities.loc[stud.activities.isnull() == 1])
# категориальная переменная. выбросов нет, 14 пропусков
# Out:
# 14

# %%
stud.activities = stud.activities.fillna('yes')
# пропуски заменю на самое частое значение

# %%
stud.activities.describe()
# Out:
# count     395
# unique      2
# top       yes
# freq      209
# Name: activities, dtype: object

# %%
"""
20 nursery — посещал детский сад (yes или no)
"""
# Out:
# '\n20 nursery — посещал детский сад (yes или no)\n'

# %%
stud.nursery.hist()
stud.nursery.describe()
# Out:
# count     379
# unique      2
# top       yes
# freq      300
# Name: nursery, dtype: object

# %%
sns.boxplot(x = stud['nursery'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.nursery.loc[stud.nursery.isnull() == 1])
# категориальная переменная. выбросов нет, 16 пропусков
# Out:
# 16

# %%
stud.nursery = stud.nursery.fillna('yes')
# пропуски заменю на самое частое значение

# %%
stud.nursery.describe()
# Out:
# count     395
# unique      2
# top       yes
# freq      316
# Name: nursery, dtype: object

# %%
"""
21 higher — хочет получить высшее образование (yes или no)
"""
# Out:
# '\n21 higher — хочет получить высшее образование (yes или no)\n'

# %%
stud.higher.hist()
stud.higher.describe()
# Out:
# count     375
# unique      2
# top       yes
# freq      356
# Name: higher, dtype: object

# %%
sns.boxplot(x = stud['higher'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.higher.loc[stud.higher.isnull() == 1])
# категориальная переменная. выбросов нет, 20 пропусков
# Out:
# 20

# %%
stud.higher = stud.higher.fillna('yes')

# %%
# пропуски заменю на самое частое значение
stud.higher.describe()
# Out:
# count     395
# unique      2
# top       yes
# freq      376
# Name: higher, dtype: object

# %%
"""
22 internet — наличие интернета дома (yes или no)
"""
# Out:
# '\n22 internet — наличие интернета дома (yes или no)\n'

# %%
stud.internet.hist()
stud.internet.describe()
# Out:
# count     361
# unique      2
# top       yes
# freq      305
# Name: internet, dtype: object

# %%
sns.boxplot(x = stud['internet'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.internet.loc[stud.internet.isnull() == 1])
# категориальная переменная. выбросов нет, 34 пропуска
# Out:
# 34

# %%
stud.internet = stud.internet.fillna('yes')
# пропуски заменю на самое частое значение

# %%
stud.internet.describe()
# Out:
# count     395
# unique      2
# top       yes
# freq      339
# Name: internet, dtype: object

# %%
"""
23 romantic — в романтических отношениях (yes или no)
"""
# Out:
# '\n23 romantic — в романтических отношениях (yes или no)\n'

# %%
stud.romantic.hist()
stud.romantic.describe()
# Out:
# count     364
# unique      2
# top        no
# freq      240
# Name: romantic, dtype: object

# %%
sns.boxplot(x = stud['romantic'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.romantic.loc[stud.romantic.isnull() == 1])
# категориальная переменная. выбросов нет, 31 пропусков
# Out:
# 31

# %%
stud.romantic = stud.romantic.fillna('no')
# пропуски заменю на самое частое значение

# %%
stud.famsup.describe()
# Out:
# count     395
# unique      2
# top       yes
# freq      258
# Name: famsup, dtype: object

# %%
"""
24 famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
"""
# Out:
# '\n24 famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)\n'

# %%
stud.famrel.hist()
stud.famrel.describe()
# Out:
# count    368.000000
# mean       3.937500
# std        0.927277
# min       -1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64

# %%
sns.boxplot(x = stud['famrel'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.famrel.loc[stud.famrel.isnull() == 1])
# категориальная переменная. выброс есть, похоже это ошибка, 27 пропусков
# Out:
# 27

# %%
stud.famrel.loc[stud.famrel == -1]
# Out:
# 25   -1.0
# Name: famrel, dtype: float64

# %%
stud.famrel[25] = stud.famrel[25] == 1 # решил заменить значение на 1
stud["famrel"] = pd.to_numeric(stud["famrel"]) # вернул тип на числовой
# Out:
# <ipython-input-1245-6dd26a32bcef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stud.famrel[25] = stud.famrel[25] == 1 # решил заменить значение
# /Users/idiamond/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
stud.famrel = stud.famrel.fillna(4)
# пропуски заменю на ближайшее к среднему

# %%
stud.famrel.describe()
# Out:
# count    395.000000
# mean       3.944304
# std        0.882392
# min        0.000000
# 25%        4.000000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: famrel, dtype: float64

# %%
"""
25 freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)
"""
# Out:
# '\n25 freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)\n'

# %%
stud.freetime.hist()
stud.freetime.describe()
# Out:
# count    384.000000
# mean       3.231771
# std        0.993940
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: freetime, dtype: float64

# %%
sns.boxplot(x = stud['freetime'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.freetime.loc[stud.freetime.isnull() == 1])
# категориальная переменная. выбросов нет, 11 пропусков
# Out:
# 11

# %%
stud.freetime = stud.freetime.fillna(3)
# пропуски заменю на значение близкое к среднему

# %%
stud.freetime.describe()
# Out:
# count    395.000000
# mean       3.225316
# std        0.980711
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: freetime, dtype: float64

# %%
"""
26 goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
"""
# Out:
# '\n26 goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)\n'

# %%
stud.goout.hist()
stud.goout.describe()
# Out:
# count    387.000000
# mean       3.105943
# std        1.115896
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: goout, dtype: float64

# %%
sns.boxplot(x = stud['goout'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.goout.loc[stud.goout.isnull() == 1])
# категориальная переменная. выбросов нет, 8 пропусков
# Out:
# 8

# %%
stud.goout = stud.goout.fillna(3)
# пропуски заменю на близкое к среднему

# %%
stud.goout.describe()
# Out:
# count    395.000000
# mean       3.103797
# std        1.104610
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: goout, dtype: float64

# %%
"""
27 health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
"""
# Out:
# '\n27 health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)\n'

# %%
stud.health.hist()
stud.health.describe()
# Out:
# count    380.000000
# mean       3.531579
# std        1.396019
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: health, dtype: float64

# %%
sns.boxplot(x = stud['health'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.health.loc[stud.health.isnull() == 1])
# категориальная переменная. выбросов нет, 15 пропусков
# Out:
# 15

# %%
stud.health = stud.health.fillna(4)
# пропуски заменю на близкое к среднему

# %%
stud.health.describe()
# Out:
# count    395.000000
# mean       3.549367
# std        1.372118
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: health, dtype: float64

# %%
"""
28 absences — количество пропущенных занятий
"""
# Out:
# '\n28 absences — количество пропущенных занятий\n'

# %%
stud.absences.hist()
stud.absences.describe()
# Out:
# count    383.000000
# mean       7.279373
# std       23.465197
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64

# %%
sns.boxplot(x = stud['absences'], y = stud['score']) 
# посмотрю как влияет на целевую переменную

# %%
len(stud.absences.loc[stud.absences.isnull() == 1])
# числовая переменная. выбросы есть, 12 пропусков
# Out:
# 12

# %%
# отфильтрую выбросы с помощью формулы межквартильного размаха
median = stud.absences.median()
IQR = stud.absences.quantile(0.75) - stud.absences.quantile(0.25)
perc25 = stud.absences.quantile(0.25)
perc75 = stud.absences.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75)
      , "IQR: {}, ".format(IQR),"Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
stud.absences.loc[stud.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 10, range = (0, 20), 
                                                                                             label = 'IQR')
plt.legend();
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, 20.0].

# %%
stud = stud.loc[stud.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)] # фильтрую выбросы

# %%
len(stud.absences.loc[stud.absences.isnull() == 1])
# Пропуски отфильтровались вместе с выбросами
# Out:
# 0

# %%
stud.absences.hist()
stud.absences.describe()
# Out:
# count    366.000000
# mean       4.603825
# std        4.965512
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        7.000000
# max       20.000000
# Name: absences, dtype: float64

# %%
sns.boxplot(x = stud['absences'], y = stud['score']) 
# более наглядно, когда выбросы отфильтрованы, влияет на score

# %%
"""
29 score — баллы по госэкзамену по математике
"""
# Out:
# '\n29 score — баллы по госэкзамену по математике\n'

# %%
pd.DataFrame(stud.score.value_counts()) # смотрю целевую переменную
# Out:
#        score
# 50.0      53
# 55.0      42
# 0.0       36
# 75.0      31
# 65.0      30
# 60.0      29
# 70.0      27
# 40.0      26
# 45.0      23
# 80.0      16
# 30.0      14
# 35.0       9
# 90.0       9
# 25.0       7
# 95.0       5
# 85.0       3
# 100.0      1

# %%
stud.score.hist()
stud.score.describe()
# Out:
# count    361.000000
# mean      51.994460
# std       22.956117
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %%
len(stud.score.loc[stud.score.isnull() == 1])
# числовая переменная, выбросов нет, есть 5 пропусков
# Out:
# 5

# %%
stud = stud.dropna(subset=['score'], axis = 0) 
"""
удаляем пропуски в целевой переменной, тк их нет смысла заменять, лучше просто удалить
благо их мало
нулевые значения оставлю, возможно это оценки учеников, 
которые пришли на экзамен но ничего не сделали.
"""

# %%
stud.score.describe()
# Out:
# count    361.000000
# mean      51.994460
# std       22.956117
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %%
"""
КОРРЕЛЯЦИОННЫЙ АНАЛИЗ для числовых переменных
"""

# %%
digital_stud = stud[['age', 'absences', 'score']]
sns.heatmap(digital_stud.corr(), annot=True)
plt.gcf().set_size_inches(10, 8)

# %%
# корреляция числовых переменных друг с другом и с целевой переменной минимальная, 
# лучше эти признаки оставить.

# %%
"""
АНАЛИЗ НОМИНАТИВНЫХ переменных
"""
# Out:
# '\nАНАЛИЗ НОМИНАТИВНЫХ переменных\n'

# %%
# Составлю боксплоты для отношения всех номинативных признаков к score

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize = (14, 4))
    sns.boxplot(y=column, x='score', 
                data=stud.loc[stud.loc[:, column].isin(stud.loc[:, column].value_counts().index[:])],
               ax=ax)
    plt.xticks()
    ax.set_title('Boxplot for ' + column)
    plt.show()

# %%
for col in ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob',
            'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup',\
            'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic',
            'famrel', 'freetime', 'goout', 'health']:
    get_boxplot(col)

# %%
"""
Визуальны осмотр боксплотов, отображающих взаимосвязь категориальных переменных с целевой
переменной score, говорит о том, что переменные 'school', 'sex', 'address', 'Medu', 'Fedu', 'Mjob', 'Fjob',
'reason', 'guardian', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 
'romantic' и другие влияют так или иначе на переменную score.

Но окончательный вывод о том, какие признаки оставить для модели, можно сделать после 
проведения статистического анализа, теста Стьюдента
"""

# %%
# Тест Стьюдента для номинативных переменных

# %%
def get_stat_dif(column):
    cols = stud.loc[:, column].value_counts().index[:10]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(stud.loc[stud.loc[:, column] == comb[0], 'score'], 
                        stud.loc[stud.loc[:, column] == comb[1], 'score']).pvalue \
            <= 0.05/len(combinations_all): # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break

# %%
for col in [
    'school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob',
            'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup',\
            'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic',
            'famrel', 'freetime', 'goout', 'health', 'age', 'absences']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки sex
# Найдены статистически значимые различия для колонки address
# Найдены статистически значимые различия для колонки Medu
# Найдены статистически значимые различия для колонки Mjob
# Найдены статистически значимые различия для колонки failures
# Найдены статистически значимые различия для колонки paid
# Найдены статистически значимые различия для колонки higher
# Найдены статистически значимые различия для колонки romantic
# Найдены статистически значимые различия для колонки absences

# %%
"""
тест показал, что наиболее влияющие на score переменные:
'sex', 'address', 'Medu', 'Mjob', 'failures', 'paid', 'higher', 'romantic', 'absences'
"""

# %%
"""
ВЫВОДЫ:
В процессе анализа данных были проанализированы все колонки датафрейма,
выбросы были найдены только в 2х колонках и то, это были единичные случаи, скорей всего ошибки.
Это говорит об общем хорошем качестве данных.
Пропуски были найдены во всех колонках кроме 'school', 'sex' и 'age'.
Были заменены на моду в категориальных переменных или значения близкие к среднему.
Также замена пропусков в Pstatus была сделана на основе данных из колонки famsize.
В целевой переменной score было всего 5 пропусков, которые были удалены.
Колонку "studytime, granular" принял решение удалить из-за полной корреляции 
с колонкой 'studytime'.
Параметры, которые наибольшим образом влияют на переменную score и которые нужно использовать
для построения модели прогноза оценок по математике это : 'sex', 'address', 'Medu', 'Mjob', 
'failures', 'paid', 'higher', 'romantic', 'absences'.
"""
